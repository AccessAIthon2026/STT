# %%
# %pip install --upgrade transformers
# %pip install --upgrade "torch" torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
import sys
print(sys.executable)
import importlib
try:
    import torch
    print('torch', torch.__version__, 'cuda available=', torch.cuda.is_available())
except Exception as e:
    print('torch import failed:', e)
print('transformers version:', importlib.import_module('transformers').__version__)
# Out:
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 5.1.0 which is incompatible.
# Requirement already satisfied: transformers in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.55.0)
# Collecting transformers
#   Downloading transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (2025.7.34)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer-slim (from transformers)
#   Downloading typer_slim-0.23.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: safetensors>=0.4.3 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.7.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Collecting shellingham (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.14.1)
# Requirement already satisfied: anyio in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.1)
# Collecting typer>=0.23.1 (from typer-slim->transformers)
#   Downloading typer-0.23.1-py3-none-any.whl.metadata (16 kB)
# Collecting click>=8.0.0 (from typer>=0.23.1->typer-slim->transformers)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer>=0.23.1->typer-slim->transformers) (14.3.2)
# Collecting annotated-doc>=0.0.2 (from typer>=0.23.1->typer-slim->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (0.1.2)
# Downloading transformers-5.1.0-py3-none-any.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.3 MB 666.9 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/10.3 MB 666.9 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/10.3 MB 664.7 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/10.3 MB 723.7 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.3/10.3 MB 809.1 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/10.3 MB 869.4 kB/s eta 0:00:11
#    ------ --------------------------------- 1.6/10.3 MB 869.4 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/10.3 MB 881.0 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/10.3 MB 923.3 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/10.3 MB 923.3 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/10.3 MB 938.8 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/10.3 MB 971.8 kB/s eta 0:00:08
#    ------------ --------------------------- 3.1/10.3 MB 995.0 kB/s eta 0:00:08
#    ------------- -------------------------- 3.4/10.3 MB 1.0 MB/s eta 0:00:07
#    -------------- ------------------------- 3.7/10.3 MB 1.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.2/10.3 MB 1.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.2/10.3 MB 1.1 MB/s eta 0:00:06
#    ------------------ --------------------- 4.7/10.3 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.2/10.3 MB 1.2 MB/s eta 0:00:05
#    --------------------- ------------------ 5.5/10.3 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.8/10.3 MB 1.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.0/10.3 MB 1.2 MB/s eta 0:00:04
#    ------------------------- -------------- 6.6/10.3 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.8/10.3 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.1/10.3 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.3/10.3 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 7.9/10.3 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.1/10.3 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.7/10.3 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.9/10.3 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 9.4/10.3 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 1.4 MB/s  0:00:07
# Downloading huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
#    ---------------------------------------- 0.0/553.3 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/553.3 kB ? eta -:--:--
#    ---------------------------------------- 553.3/553.3 kB 1.4 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 4.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.1/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.6 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.7 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.2 MB/s  0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.23.1-py3-none-any.whl (3.4 kB)
# Downloading typer-0.23.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: shellingham, hf-xet, click, annotated-doc, typer, typer-slim, huggingface-hub, tokenizers, transformers
#
#    ---------------------------------------- 0/9 [shellingham]
#    ---- ----------------------------------- 1/9 [hf-xet]
#    -------- ------------------------------- 2/9 [click]
#    -------- ------------------------------- 2/9 [click]
#    -------- ------------------------------- 2/9 [click]
#    -------- ------------------------------- 2/9 [click]
#    ------------- -------------------------- 3/9 [annotated-doc]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#    ----------------- ---------------------- 4/9 [typer]
#   Attempting uninstall: huggingface-hub
#    ----------------- ---------------------- 4/9 [typer]
#     Found existing installation: huggingface-hub 0.34.4
#    ----------------- ---------------------- 4/9 [typer]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#     Uninstalling huggingface-hub-0.34.4:
#    -------------------------- ------------- 6/9 [huggingface-hub]
#       Successfully uninstalled huggingface-hub-0.34.4
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#   Attempting uninstall: tokenizers
#    -------------------------- ------------- 6/9 [huggingface-hub]
#     Found existing installation: tokenizers 0.21.4
#    -------------------------- ------------- 6/9 [huggingface-hub]
#     Uninstalling tokenizers-0.21.4:
#    -------------------------- ------------- 6/9 [huggingface-hub]
#       Successfully uninstalled tokenizers-0.21.4
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ------------------------------- -------- 7/9 [tokenizers]
#   Attempting uninstall: transformers
#    ------------------------------- -------- 7/9 [tokenizers]
#     Found existing installation: transformers 4.55.0
#    ------------------------------- -------- 7/9 [tokenizers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#     Uninstalling transformers-4.55.0:
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#       Successfully uninstalled transformers-4.55.0
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ---------------------------------------- 9/9 [transformers]
#
# Successfully installed annotated-doc-0.0.4 click-8.3.1 hf-xet-1.2.0 huggingface-hub-1.4.1 shellingham-1.5.4 tokenizers-0.22.2 transformers-5.1.0 typer-0.23.1 typer-slim-0.23.1
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.8.0)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.10.0%2Bcpu-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.25.0%2Bcpu-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.10.0%2Bcpu-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: setuptools in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torchvision) (2.3.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.10.0%2Bcpu-cp313-cp313-win_amd64.whl (113.7 MB)
#    ---------------------------------------- 0.0/113.7 MB ? eta -:--:--
#    ---------------------------------------- 0.8/113.7 MB 5.8 MB/s eta 0:00:20
#     --------------------------------------- 1.6/113.7 MB 5.7 MB/s eta 0:00:20
#     --------------------------------------- 1.8/113.7 MB 4.4 MB/s eta 0:00:26
#    ------- -------------------------------- 19.9/113.7 MB 2.4 MB/s eta 0:00:40
#    ------- -------------------------------- 20.2/113.7 MB 2.4 MB/s eta 0:00:40
#    ------- -------------------------------- 21.0/113.7 MB 2.4 MB/s eta 0:00:40
#    ------- -------------------------------- 21.2/113.7 MB 2.4 MB/s eta 0:00:40
#    ------- -------------------------------- 21.8/113.7 MB 2.3 MB/s eta 0:00:40
#    ------- -------------------------------- 22.3/113.7 MB 2.4 MB/s eta 0:00:39
#    -------- ------------------------------- 22.8/113.7 MB 2.4 MB/s eta 0:00:39
#    -------- ------------------------------- 23.1/113.7 MB 2.4 MB/s eta 0:00:39
#    -------- ------------------------------- 23.3/113.7 MB 2.3 MB/s eta 0:00:40
#    -------- ------------------------------- 24.1/113.7 MB 2.3 MB/s eta 0:00:39
#    -------- ------------------------------- 24.6/113.7 MB 2.3 MB/s eta 0:00:39
#    -------- ------------------------------- 24.9/113.7 MB 2.3 MB/s eta 0:00:39
#    --------- ------------------------------ 25.7/113.7 MB 2.3 MB/s eta 0:00:38
#    --------- ------------------------------ 26.0/113.7 MB 2.3 MB/s eta 0:00:38
#    --------- ------------------------------ 26.5/113.7 MB 2.3 MB/s eta 0:00:38
#    --------- ------------------------------ 27.0/113.7 MB 2.3 MB/s eta 0:00:38
#    --------- ------------------------------ 27.8/113.7 MB 2.3 MB/s eta 0:00:37
#    --------- ------------------------------ 28.0/113.7 MB 2.3 MB/s eta 0:00:37
#    ---------- ----------------------------- 28.6/113.7 MB 2.3 MB/s eta 0:00:37
#    ---------- ----------------------------- 28.8/113.7 MB 2.3 MB/s eta 0:00:37
#    ---------- ----------------------------- 29.4/113.7 MB 2.3 MB/s eta 0:00:37
#    ---------- ----------------------------- 29.9/113.7 MB 2.3 MB/s eta 0:00:37
#    ---------- ----------------------------- 30.4/113.7 MB 2.3 MB/s eta 0:00:36
#    ---------- ----------------------------- 30.9/113.7 MB 2.3 MB/s eta 0:00:36
#    ----------- ---------------------------- 31.5/113.7 MB 2.3 MB/s eta 0:00:36
#    ----------- ---------------------------- 32.2/113.7 MB 2.4 MB/s eta 0:00:35
#    ----------- ---------------------------- 33.0/113.7 MB 2.4 MB/s eta 0:00:35
#    ----------- ---------------------------- 33.6/113.7 MB 2.4 MB/s eta 0:00:34
#    ----------- ---------------------------- 34.1/113.7 MB 2.4 MB/s eta 0:00:34
# ...
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.10.0+cpu torchaudio-2.10.0+cpu torchvision-0.25.0+cpu
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\~orch'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 5.1.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\ishir\AppData\Local\Programs\Python\Python313\python.exe
# torch 2.8.0+cpu cuda available= False
# transformers version: 4.55.0

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("test_audio.wav")

print(result["text"])
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:52<00:00, 2.79MiB/s]
# c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 import whisper
#       3 model = whisper.load_model("base")
# ----> 4 result = model.transcribe("test_audio.wav")
#       6 print(result["text"])
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\whisper\transcribe.py:139, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, carry_initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     136     decode_options["fp16"] = False
#     138 # Pad 30-seconds of silence to the input audio, for slicing
# --> 139 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     140 content_frames = mel.shape[-1] - N_FRAMES
#     141 content_duration = float(content_frames * HOP_LENGTH / SAMPLE_RATE)
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\whisper\audio.py:140, in log_mel_spectrogram(audio, n_mels, padding, device)
#     138 if not torch.is_tensor(audio):
#     139     if isinstance(audio, str):
# --> 140         audio = load_audio(audio)
#     141     audio = torch.from_numpy(audio)
#     143 if device is not None:
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\site-packages\whisper\audio.py:58, in load_audio(file, sr)
#      56 # fmt: on
#      57 try:
# ---> 58     out = run(cmd, capture_output=True, check=True).stdout
#      59 except CalledProcessError as e:
#      60     raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#     556         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\ishir\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1552 # Start the process
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)   1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#    1569     self._close_pipe_fds(p2cread, p2cwrite,
#    1570                          c2pread, c2pwrite,
#    1571                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
